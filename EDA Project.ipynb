# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Human Resources & Kyphosis & Cancer & Daily Stock Project</b></p>

# %% [markdown]
# # Human Resources Project

# %% [markdown]
# ## IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', None)  
pd.set_option('display.max_colwidth', None)

# %%
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df.shape
# Out:
# (1470, 35)

# %%
hr_df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr_df.columns = [col.lower() for col in hr_df]
hr_df.columns
# Out:
# Index(['age', 'monthlyincome', 'attrition', 'businesstravel', 'dailyrate',
#        'department', 'distancefromhome', 'education', 'educationfield',
#        'employeecount', 'employeenumber', 'environmentsatisfaction', 'gender',
#        'hourlyrate', 'jobinvolvement', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager'],
#       dtype='object')

# %%
hr_df.head()
# Out:
#    age  monthlyincome attrition     businesstravel  dailyrate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                department  distancefromhome  education educationfield  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    employeecount  employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0              1             1.0                        2  Female          94
# ...

# %%
hr_df.tail()
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       employeecount  employeenumber  environmentsatisfaction gender  \
# ...

# %%
numeric_columns = hr_df.select_dtypes(include=['number']).columns
average_values = hr_df[numeric_columns].mean()
average_values
# Out:
# age                            36.923810
# monthlyincome                6505.155419
# dailyrate                     802.485714
# distancefromhome                9.192517
# education                       2.912925
# employeecount                   1.000000
# employeenumber               1025.556161
# environmentsatisfaction         2.721769
# hourlyrate                     65.891156
# jobinvolvement                  2.729932
# joblevel                        2.063946
# jobsatisfaction                 2.728571
# monthlyrate                 14310.966621
# numcompaniesworked              2.693197
# percentsalaryhike              15.206263
# performancerating               3.153165
# relationshipsatisfaction        2.712245
# standardhours                  80.000000
# stockoptionlevel                0.793878
# totalworkingyears              11.279592
# trainingtimeslastyear           2.799320
# worklifebalance                 2.761224
# yearsatcompany                  7.008163
# ...

# %%
hr_df.sample(10)
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 1398   33         5968.0        No  Travel_Frequently       1303
# 1342   34         9713.0        No      Travel_Rarely       1480
# 956    56        19717.0        No      Travel_Rarely        206
# 717    27         2811.0        No      Travel_Rarely       1134
# 915    21         2625.0       Yes  Travel_Frequently        251
# 71     29         2703.0        No      Travel_Rarely       1328
# 1374   58        17875.0        No      Travel_Rarely        605
# 695    37        10609.0       Yes      Travel_Rarely        625
# 1138   50        11245.0        No  Travel_Frequently       1234
# 831    31         2610.0       Yes  Travel_Frequently        874
#
#                   department  distancefromhome  education    educationfield  \
# 1398  Research & Development                 7          2     Life Sciences
# 1342                   Sales                 4          3     Life Sciences
# ...

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1470 non-null   int64
#  1   monthlyincome             1467 non-null   float64
#  2   attrition                 1470 non-null   object
#  3   businesstravel            1470 non-null   object
#  4   dailyrate                 1470 non-null   int64
#  5   department                1469 non-null   object
#  6   distancefromhome          1470 non-null   int64
#  7   education                 1470 non-null   int64
#  8   educationfield            1469 non-null   object
#  9   employeecount             1470 non-null   int64
#  10  employeenumber            1469 non-null   float64
#  11  environmentsatisfaction   1470 non-null   int64
#  12  gender                    1469 non-null   object
# ...

# %%
# Convert categorical columns to 'category' type
categorical_columns = ['attrition', 'businesstravel', 
    'gender', 'maritalstatus', 'over18', 'overtime']

hr_df[categorical_columns] = hr_df[categorical_columns].astype('category')

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1470 non-null   int64
#  1   monthlyincome             1467 non-null   float64
#  2   attrition                 1470 non-null   category
#  3   businesstravel            1470 non-null   category
#  4   dailyrate                 1470 non-null   int64
#  5   department                1469 non-null   object
#  6   distancefromhome          1470 non-null   int64
#  7   education                 1470 non-null   int64
#  8   educationfield            1469 non-null   object
#  9   employeecount             1470 non-null   int64
#  10  employeenumber            1469 non-null   float64
#  11  environmentsatisfaction   1470 non-null   int64
#  12  gender                    1469 non-null   category
# ...

# %%
hr_df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# age                       1470.0     36.923810     9.135373    18.0    30.00
# monthlyincome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# dailyrate                 1470.0    802.485714   403.509100   102.0   465.00
# distancefromhome          1470.0      9.192517     8.106864     1.0     2.00
# education                 1470.0      2.912925     1.024165     1.0     2.00
# employeecount             1470.0      1.000000     0.000000     1.0     1.00
# employeenumber            1469.0   1025.556161   601.646166     1.0   492.00
# environmentsatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# hourlyrate                1470.0     65.891156    20.329428    30.0    48.00
# jobinvolvement            1470.0      2.729932     0.711561     1.0     2.00
# joblevel                  1470.0      2.063946     1.106940     1.0     1.00
# ...

# %% [markdown]
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
hr_df.age.mean()
# Out:
# 36.923809523809524

# %%
hr_df.age.max()
# Out:
# 60

# %%
hr_df.age.min()
# Out:
# 18

# %% [markdown]
# ## DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
hr_df.isnull()
# Out:
#         age  monthlyincome  attrition  businesstravel  dailyrate  department  \
# 0     False          False      False           False      False       False
# 1     False           True      False           False      False       False
# 2     False          False      False           False      False       False
# 3     False          False      False           False      False       False
# 4     False          False      False           False      False       False
# ...     ...            ...        ...             ...        ...         ...
# 1465  False          False      False           False      False       False
# 1466  False          False      False           False      False       False
# 1467  False          False      False           False      False       False
# 1468  False          False      False           False      False       False
# 1469  False          False      False           False      False       False
#
# ...

# %%
hr_df.isnull().sum()
# Out:
# age                         0
# monthlyincome               3
# attrition                   0
# businesstravel              0
# dailyrate                   0
# department                  1
# distancefromhome            0
# education                   0
# educationfield              1
# employeecount               0
# employeenumber              1
# environmentsatisfaction     0
# gender                      1
# hourlyrate                  0
# jobinvolvement              0
# joblevel                    0
# jobrole                     1
# jobsatisfaction             0
# maritalstatus               1
# monthlyrate                 2
# numcompaniesworked          0
# over18                      0
# overtime                    0
# percentsalaryhike           1
# performancerating           1
# relationshipsatisfaction    0
# standardhours               0
# stockoptionlevel            0
# totalworkingyears           0
# trainingtimeslastyear       0
# worklifebalance             0
# ...

# %%
hr_df.isnull().sum()[hr_df.isnull().sum() > 0]
# Out:
# monthlyincome        3
# department           1
# educationfield       1
# employeenumber       1
# gender               1
# jobrole              1
# maritalstatus        1
# monthlyrate          2
# percentsalaryhike    1
# performancerating    1
# dtype: int64

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as msno
msno.matrix(hr_df)
# Out:
# <Axes: >

# %%
hr_df.dropna(inplace = True)

# %%
msno.matrix(hr_df)
# Out:
# <Axes: >

# %%
hr_df.isnull().sum()[hr_df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df.columns = [col.lower() for col in hr_df]
hr_df.columns
# Out:
# Index(['age', 'monthlyincome', 'attrition', 'businesstravel', 'dailyrate',
#        'department', 'distancefromhome', 'education', 'educationfield',
#        'employeecount', 'employeenumber', 'environmentsatisfaction', 'gender',
#        'hourlyrate', 'jobinvolvement', 'joblevel', 'jobrole',
#        'jobsatisfaction', 'maritalstatus', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager'],
#       dtype='object')

# %%
hr_df.isnull().sum()[hr_df.isnull().sum() > 0]
# Out:
# monthlyincome        3
# department           1
# educationfield       1
# employeenumber       1
# gender               1
# jobrole              1
# maritalstatus        1
# monthlyrate          2
# percentsalaryhike    1
# performancerating    1
# dtype: int64

# %%
hr_df['employeenumber'].fillna(-1, inplace=True)

# %%
hr_df.dropna(subset=['performancerating'], inplace=True)

# %%
numerical_columns = ['monthlyincome', 'monthlyrate', 'percentsalaryhike']
for col in numerical_columns:
    hr_df[col].fillna(hr_df[col].median(), inplace=True)

# %%
categorical_columns = ['department', 'educationfield', 'gender', 'jobrole', 'maritalstatus']
for col in categorical_columns:
    hr_df[col].fillna(hr_df[col].mode()[0], inplace=True)

# %%
hr_df.isnull().sum()[hr_df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
hr_df['monthlyrate'].median()
# Out:
# 14242.0

# %%
hr_df.isnull().sum()[hr_df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
hr_df.sample(5)
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 571    26         4364.0        No  Travel_Frequently        575
# 304    39         9613.0        No      Travel_Rarely       1132
# 1180   36         2013.0        No      Travel_Rarely        311
# 499    33         7104.0        No      Travel_Rarely       1216
# 940    39         3904.0       Yes      Travel_Rarely        360
#
#                   department  distancefromhome  education educationfield  \
# 571   Research & Development                 1          2  Life Sciences
# 304   Research & Development                 1          3        Medical
# 1180  Research & Development                 7          3  Life Sciences
# 499                    Sales                 8          4      Marketing
# 940   Research & Development                23          3        Medical
#
#       employeecount  employeenumber  environmentsatisfaction  gender  \
# ...

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
# hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df['education'].nunique()
# Out:
# 5

# %%
hr_df[['education']]
# Out:
#       education
# 0             2
# 1             1
# 2             2
# 3             4
# 4             1
# ...         ...
# 1465          2
# 1466          1
# 1467          3
# 1468          3
# 1469          3
#
# [1469 rows x 1 columns]

# %%
hr_df_encoded = pd.get_dummies(hr_df, columns=['educationfield'], prefix='edu')

hr_df_encoded.head()
# Out:
#    age  monthlyincome attrition     businesstravel  dailyrate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49         4908.0        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                department  distancefromhome  education  employeecount  \
# 0                   Sales                 1          2              1
# 1  Research & Development                 8          1              1
# 2  Research & Development                 2          2              1
# 3  Research & Development                 3          4              1
# 4  Research & Development                 2          1              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0             1.0                        2  Female          94
# ...

# %% [markdown]
# ## PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
import pandas as pd
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34])

# %%
# Normalization is conducted to make feature values range from 0 to 1
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#hr_df['age'] = scaler.fit_transform(hr_df['age'].values.reshape(-1,1))

# %%
# hr_df['age']

# %%
hr_df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# ...

# %% [markdown]
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Select numeric columns for standardization
numeric_columns = hr_df.select_dtypes(include=['int64', 'float64']).columns

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the numeric columns
hr_df_scaled = hr_df.copy()  # Create a copy of the original DataFrame
hr_df_scaled[numeric_columns] = scaler.fit_transform(hr_df[numeric_columns])

hr_df_scaled.head()
# Out:
#         age  monthlyincome attrition     businesstravel  dailyrate  \
# 0  0.448737      -0.108349       Yes      Travel_Rarely   0.743577
# 1  1.326201      -0.338864        No  Travel_Frequently  -1.297192
# 2  0.010005      -0.937565       Yes      Travel_Rarely   1.415568
# 3 -0.428727      -0.763563        No  Travel_Frequently   1.462681
# 4 -1.086825      -0.644800        No      Travel_Rarely  -0.523534
#
#                department  distancefromhome  education educationfield  \
# 0                   Sales         -1.011286  -0.891329  Life Sciences
# 1  Research & Development         -0.147649  -1.867737  Life Sciences
# 2  Research & Development         -0.887910  -0.891329          Other
# 3  Research & Development         -0.764533   1.061486  Life Sciences
# 4  Research & Development         -0.887910  -1.867737        Medical
#
#    employeecount  employeenumber  environmentsatisfaction  gender  hourlyrate  \
# ...

# %%
scaled_mean = hr_df_scaled[numeric_columns].mean()
scaled_std = hr_df_scaled[numeric_columns].std()

# %%
scaled_mean
scaled_std
# Out:
# age                         1.000341
# monthlyincome               1.000341
# dailyrate                   1.000341
# distancefromhome            1.000341
# education                   1.000341
# employeecount               0.000000
# employeenumber              1.000341
# environmentsatisfaction     1.000341
# hourlyrate                  1.000341
# jobinvolvement              1.000341
# joblevel                    1.000341
# jobsatisfaction             1.000341
# monthlyrate                 1.000341
# numcompaniesworked          1.000341
# percentsalaryhike           1.000341
# performancerating           1.000341
# relationshipsatisfaction    1.000341
# standardhours               0.000000
# stockoptionlevel            1.000341
# totalworkingyears           1.000341
# trainingtimeslastyear       1.000341
# worklifebalance             1.000341
# yearsatcompany              1.000341
# yearsincurrentrole          1.000341
# yearssincelastpromotion     1.000341
# ...

# %% [markdown]
# ## PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
# hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
filtered_df = hr_df[(hr_df['age'] > 30)]
filtered_df
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1463   31         9936.0        No         Non-Travel        325
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
filtered_df2 = hr_df[(hr_df['age'] > 30) & (hr_df['department'] == 'Research & Development')]
filtered_df2
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 5      32         3068.0        No  Travel_Frequently       1005
# 8      38         9526.0        No  Travel_Frequently        216
# ...   ...            ...       ...                ...        ...
# 1458   35         2977.0        No      Travel_Rarely        287
# 1463   31         9936.0        No         Non-Travel        325
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
filtered_df3 = hr_df[hr_df['age'].between(30, 50)]
filtered_df3
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1463   31         9936.0        No         Non-Travel        325
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
filtered_df2 = hr_df[(hr_df['age'].between(30, 50)) & (hr_df['department'] == 'Research & Development')]
filtered_df2.head()
# Out:
#    age  monthlyincome attrition     businesstravel  dailyrate  \
# 1   49         4908.0        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 5   32         3068.0        No  Travel_Frequently       1005
# 7   30         2693.0        No      Travel_Rarely       1358
#
#                department  distancefromhome  education educationfield  \
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 5  Research & Development                 2          2  Life Sciences
# 7  Research & Development                24          1  Life Sciences
#
#    employeecount  employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 1              1             2.0                        3    Male          61
# ...

# %% [markdown]
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
high_performers = hr_df[hr_df['dailyrate'] >= 1450]
high_performers.head()
# Out:
#      age  monthlyincome attrition     businesstravel  dailyrate  \
# 31    44         6465.0        No      Travel_Rarely       1459
# 52    44         5454.0        No      Travel_Rarely       1488
# 110   51         7484.0        No  Travel_Frequently       1456
# 117   36         9738.0        No  Travel_Frequently       1467
# 155   29         4319.0        No         Non-Travel       1496
#
#                  department  distancefromhome  education    educationfield  \
# 31   Research & Development                10          4             Other
# 52                    Sales                 1          5         Marketing
# 110  Research & Development                 1          4           Medical
# 117                   Sales                11          2  Technical Degree
# 155  Research & Development                 1          1  Technical Degree
#
#      employeecount  employeenumber  environmentsatisfaction  gender  \
# ...

# %%
total_daily_rate = high_performers['dailyrate'].sum()
total_daily_rate
# Out:
# 73749

# %% [markdown]
# ## PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
df_cleaned = hr_df.drop(['employeecount', 'standardhours', 'over18'], axis=1,)

# %%
df_cleaned
# Out:
#       age  monthlyincome attrition     businesstravel  dailyrate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   department  distancefromhome  education educationfield  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
attrition_count = df_cleaned['attrition'].value_counts()
attrition_count
# Out:
# attrition
# No     1232
# Yes     237
# Name: count, dtype: int64

# %%
hr_df.drop(['employeenumber'], axis=1, inplace=True)

# %%
employees_who_left = hr_df[hr_df['attrition'] == 'Yes']
employees_who_left.head()
# Out:
#     age  monthlyincome attrition businesstravel  dailyrate  \
# 0    41         5993.0       Yes  Travel_Rarely       1102
# 2    37         2090.0       Yes  Travel_Rarely       1373
# 14   28         2028.0       Yes  Travel_Rarely        103
# 21   36         3407.0       Yes  Travel_Rarely       1218
# 24   34         2960.0       Yes  Travel_Rarely        699
#
#                 department  distancefromhome  education educationfield  \
# 0                    Sales                 1          2  Life Sciences
# 2   Research & Development                 2          2          Other
# 14  Research & Development                24          3  Life Sciences
# 21                   Sales                 9          4  Life Sciences
# 24  Research & Development                 6          1        Medical
#
#     employeecount  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        2  Female          94
# ...

# %%
num_of_left_employees = employees_who_left.shape[0]
num_of_left_employees
# Out:
# 237

# %% [markdown]
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
stayed_employees = hr_df[hr_df['attrition'] == 'No']
stayed_employees.head()
# Out:
#    age  monthlyincome attrition     businesstravel  dailyrate  \
# 1   49         4908.0        No  Travel_Frequently        279
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
# 7   30         2693.0        No      Travel_Rarely       1358
#
#                department  distancefromhome  education educationfield  \
# 1  Research & Development                 8          1  Life Sciences
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
# 7  Research & Development                24          1  Life Sciences
#
#    employeecount  environmentsatisfaction  gender  hourlyrate  jobinvolvement  \
# 1              1                        3    Male          61               2
# ...

# %%
sum_stayed = stayed_employees.describe()
sum_stayed
# Out:
#                age  monthlyincome    dailyrate  distancefromhome    education  \
# count  1232.000000    1232.000000  1232.000000       1232.000000  1232.000000
# mean     37.543831    6835.938312   812.089286          8.920455     2.926948
# std       8.870933    4818.771042   403.108374          8.014112     1.027417
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.750000   477.000000          2.000000     2.000000
# 50%      36.000000    5205.000000   815.000000          7.000000     3.000000
# 75%      43.000000    8834.750000  1174.500000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        employeecount  environmentsatisfaction   hourlyrate  jobinvolvement  \
# count         1232.0              1232.000000  1232.000000     1232.000000
# mean             1.0                 2.771104    65.939935        2.769481
# ...

# %%
sum_left = employees_who_left.describe()
sum_left
# Out:
#               age  monthlyincome    dailyrate  distancefromhome   education  \
# count  237.000000     237.000000   237.000000        237.000000  237.000000
# mean    33.607595    4772.164557   750.362869         10.632911    2.839662
# std      9.689350    3632.387994   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2373.000000   408.000000          3.000000    2.000000
# 50%     32.000000    3202.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5828.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        employeecount  environmentsatisfaction  hourlyrate  jobinvolvement  \
# count          237.0               237.000000  237.000000      237.000000
# mean             1.0                 2.464135   65.573840        2.518987
# ...

# %%
comparison = sum_stayed.loc['mean'] - sum_left.loc['mean']
comparison
# Out:
# age                            3.936236
# monthlyincome               2063.773755
# dailyrate                     61.726417
# distancefromhome              -1.712457
# education                      0.087286
# employeecount                  0.000000
# environmentsatisfaction        0.306969
# hourlyrate                     0.366095
# jobinvolvement                 0.250493
# joblevel                       0.509785
# jobsatisfaction                0.311678
# monthlyrate                 -292.698439
# numcompaniesworked            -0.296448
# percentsalaryhike              0.130226
# performancerating             -0.003521
# relationshipsatisfaction       0.136233
# standardhours                  0.000000
# stockoptionlevel               0.315918
# totalworkingyears              3.618099
# trainingtimeslastyear          0.208320
# worklifebalance                0.123428
# yearsatcompany                 2.243387
# yearsincurrentrole             1.584871
# ...

# %%
# 1) Employees who stayed are older on average compared to those who left. Which means younger employees are more likely to leave
# 2) Employees who stayed have a higher average income. Which means lower income may be a factor in attrition.
# 3) Employees who stayed live slightly closer to work compared to those who left. Which means longer commutes may contribute to attrition.
# 4) Employees who stayed have more work experience compared to those who left. Which means less experienced employees may be more likely to leave.
# 5) Employees who stayed have been with the company longer compared to those who left. Which means shorter tenure may indicate dissatisfaction or better opportunities elsewhere.

# Note:
     # Employees who stayed tend to be older, higher-paid, more experienced, and have longer tenures.

    # Employees who left are younger, lower-paid, less experienced, and have shorter tenures.

    # Factors like income, commute distance, and job satisfaction may play a significant role in attrition.

# %% [markdown]
# ## PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
# hr_df = pd.read_csv('Human_Resources.csv')
# hr_df

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
def increase_by_10_percent(x):
    return x * 1.10

# %%
hr_df['dailyrate'] = hr_df['dailyrate'].apply(increase_by_10_percent)
hr_df[['dailyrate']].head()
# Out:
#    dailyrate
# 0     1212.2
# 1      306.9
# 2     1510.3
# 3     1531.2
# 4      650.1

# %% [markdown]
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
def double_and_add_100(x):
    return (x * 2) + 100

# %%
hr_df['dailyrate'] = hr_df['dailyrate'].apply(double_and_add_100)

# %%
total_daily_rate_updated = hr_df['dailyrate'].sum()
total_daily_rate_updated
# Out:
# 2739226.0

# %% [markdown]
# ## HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
plt.figure(figsize=(12, 6))

# Histogram for MonthlyIncome
plt.subplot(1, 2, 1)
sns.histplot(hr_df['monthlyincome'], kde=True, color='blue', bins=30)
plt.title('Monthly Income Distribution')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')

# Histogram for TotalWorkingYears
plt.subplot(1, 2, 2)
sns.histplot(hr_df['totalworkingyears'], kde=True, color='green', bins=30)
plt.title('Total Working Years Distribution')
plt.xlabel('Total Working Years')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 12))

# Scatter plot: JobLevel vs TotalWorkingYears
plt.subplot(2, 2, 1)
sns.scatterplot(x='totalworkingyears', y='joblevel', data=hr_df, color='purple')
plt.title('Job Level vs Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Job Level')

# Scatter plot: MonthlyIncome vs JobLevel
plt.subplot(2, 2, 2)
sns.scatterplot(x='joblevel', y='monthlyincome', data=hr_df, color='orange')
plt.title('Monthly Income vs Job Level')
plt.xlabel('Job Level')
plt.ylabel('Monthly Income')

# Scatter plot: MonthlyIncome vs TotalWorkingYears
plt.subplot(2, 2, 3)
sns.scatterplot(x='totalworkingyears', y='monthlyincome', data=hr_df, color='red')
plt.title('Monthly Income vs Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Monthly Income')

# Scatter plot: Age vs MonthlyIncome
plt.subplot(2, 2, 4)
sns.scatterplot(x='age', y='monthlyincome', data=hr_df, color='blue')
plt.title('Monthly Income vs Age')
plt.xlabel('Age')
plt.ylabel('Monthly Income')

plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = hr_df[['monthlyincome', 'totalworkingyears', 'joblevel', 'age']].corr()
correlation_matrix
# Out:
#                    monthlyincome  totalworkingyears  joblevel       age
# monthlyincome           1.000000           0.773217  0.949858  0.499418
# totalworkingyears       0.773217           1.000000  0.782517  0.681587
# joblevel                0.949858           0.782517  1.000000  0.512367
# age                     0.499418           0.681587  0.512367  1.000000

# %%
numeric_df = hr_df.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix (Numeric Columns Only)')
plt.show()

# %% [markdown]
# - **Change the color of the heatmap [External Research is Required]**

# %%
numeric_df = hr_df.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Plot heatmap with a custom color map
plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    cmap='viridis', 
    fmt='.2f', 
    vmin=-1, 
    vmax=1, 
    linewidths=0.5,  
    linecolor='black' 
)
plt.title('Correlation Matrix (Numeric Columns Only)')
plt.show()

# %% [markdown]
# # Kyphosis Project

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
kp_df = pd.read_csv('kyphosis.csv')
kp_df
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
kp_df.columns = [col.lower() for col in kp_df]
kp_df.columns
# Out:
# Index(['kyphosis', 'age', 'number', 'start'], dtype='object')

# %%
kp_df.head()
# Out:
#   kyphosis  age  number  start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
kp_df.tail()
# Out:
#    kyphosis  age  number  start
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
kp_df.sample(5)
# Out:
#    kyphosis  age  number  start
# 41   absent   35       3     13
# 42   absent  143       9      3
# 4    absent    1       4     15
# 43   absent   61       4      1
# 17   absent  175       5     13

# %%
kp_df.shape
# Out:
# (81, 4)

# %%
kp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   kyphosis  81 non-null     object
#  1   age       81 non-null     int64
#  2   number    81 non-null     int64
#  3   start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
kp_df.isnull().sum()
# Out:
# kyphosis    0
# age         0
# number      0
# start       0
# dtype: int64

# %%
def convert_age_to_years(age_in_months):
    return age_in_months / 12
kp_df['age_in_years'] = kp_df['age'].apply(convert_age_to_years)

kp_df[['age', 'age_in_years']].head()
# Out:
#    age  age_in_years
# 0   71      5.916667
# 1  158     13.166667
# 2  128     10.666667
# 3    2      0.166667
# 4    1      0.083333

# %%
kp_df.head()
# Out:
#   kyphosis  age  number  start  age_in_years
# 0   absent   71       3      5      5.916667
# 1   absent  158       3     14     13.166667
# 2  present  128       4      5     10.666667
# 3   absent    2       5      1      0.166667
# 4   absent    1       4     15      0.083333

# %%
kp_df['age_in_years'].mean()
# Out:
# 6.971193415637861

# %%
kp_df['age_in_years'].min()
# Out:
# 0.08333333333333333

# %%
kp_df['age_in_years'].max()
# Out:
# 17.166666666666668

# %%
age_summary = kp_df['age_in_years'].describe()
age_summary
# Out:
# count    81.000000
# mean      6.971193
# std       4.842021
# min       0.083333
# 25%       2.166667
# 50%       7.250000
# 75%      10.833333
# max      17.166667
# Name: age_in_years, dtype: float64

# %%
average_age_years_2 = age_summary['mean']
average_age_years_2
# Out:
# 6.971193415637861

# %%
min_age_years_2 = age_summary['min']
min_age_years_2
# Out:
# 0.08333333333333333

# %%
max_age_years_2 = age_summary['max']
max_age_years_2
# Out:
# 17.166666666666668

# %%
correlation_matrix = kp_df.select_dtypes(include=['number']).corr()

# %%
plt.figure(figsize=(14, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title('Correlation Matrix')
plt.show()

# %%
kp_df['age'].dtype
# Out:
# dtype('int64')

# %%
kp_df['age'] = kp_df['age'].astype('float64')

# %%
kp_df['age'].dtype
# Out:
# dtype('float64')

# %%
kp_df
# Out:
#    kyphosis    age  number  start  age_in_years
# 0    absent   71.0       3      5      5.916667
# 1    absent  158.0       3     14     13.166667
# 2   present  128.0       4      5     10.666667
# 3    absent    2.0       5      1      0.166667
# 4    absent    1.0       4     15      0.083333
# ..      ...    ...     ...    ...           ...
# 76  present  157.0       3     13     13.083333
# 77   absent   26.0       7     13      2.166667
# 78   absent  120.0       2     13     10.000000
# 79  present   42.0       7      6      3.500000
# 80   absent   36.0       4     13      3.000000
#
# [81 rows x 5 columns]

# %%
kp_df_sorted = kp_df.sort_values(by='age')
kp_df_sorted
# Out:
#    kyphosis    age  number  start  age_in_years
# 36   absent    1.0       3      9      0.083333
# 15   absent    1.0       3     16      0.083333
# 13   absent    1.0       4     12      0.083333
# 4    absent    1.0       4     15      0.083333
# 5    absent    1.0       2     16      0.083333
# ..      ...    ...     ...    ...           ...
# 17   absent  175.0       5     13     14.583333
# 49   absent  177.0       2     14     14.750000
# 75   absent  178.0       4     15     14.833333
# 66   absent  195.0       2     17     16.250000
# 73   absent  206.0       4     10     17.166667
#
# [81 rows x 5 columns]

# %%
youngest_child = kp_df_sorted.iloc[0]
youngest_child
# Out:
# kyphosis          absent
# age                  1.0
# number                 3
# start                  9
# age_in_years    0.083333
# Name: 36, dtype: object

# %%
oldest_child = kp_df_sorted.iloc[-1]
oldest_child
# Out:
# kyphosis           absent
# age                 206.0
# number                  4
# start                  10
# age_in_years    17.166667
# Name: 73, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
 # Standardization using StandardScaler
scaler_standard = StandardScaler()
kp_df['Age_standardized'] = scaler_standard.fit_transform(kp_df[['age']])
kp_df['Age_standardized']
# Out:
# 0    -0.219143
# 1     1.287494
# 2     0.767964
# 3    -1.414063
# 4    -1.431381
#         ...
# 76    1.270177
# 77   -0.998439
# 78    0.629423
# 79   -0.721356
# 80   -0.825262
# Name: Age_standardized, Length: 81, dtype: float64

# %%
scaler_minmax = MinMaxScaler()
kp_df['Age_normalized'] = scaler_minmax.fit_transform(kp_df[['age']])
kp_df['Age_normalized']
# Out:
# 0     0.341463
# 1     0.765854
# 2     0.619512
# 3     0.004878
# 4     0.000000
#         ...
# 76    0.760976
# 77    0.121951
# 78    0.580488
# 79    0.200000
# 80    0.170732
# Name: Age_normalized, Length: 81, dtype: float64

# %%
kp_df['Age_standardized'].mean()
# Out:
# 1.0005713678720547e-16

# %%
kp_df['Age_standardized'].std()
# Out:
# 1.0062305898749055

# %%
kp_df['Age_normalized'].min()
# Out:
# 0.0

# %%
kp_df['Age_normalized'].max()
# Out:
# 1.0

# %%
kp_df.head()
# Out:
#   kyphosis    age  number  start  age_in_years  Age_standardized  \
# 0   absent   71.0       3      5      5.916667         -0.219143
# 1   absent  158.0       3     14     13.166667          1.287494
# 2  present  128.0       4      5     10.666667          0.767964
# 3   absent    2.0       5      1      0.166667         -1.414063
# 4   absent    1.0       4     15      0.083333         -1.431381
#
#    Age_normalized
# 0        0.341463
# 1        0.765854
# 2        0.619512
# 3        0.004878
# 4        0.000000

# %% [markdown]
# # Cancer Project

# %%
cancer_df = pd.read_csv('cancer.csv')
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
cancer_df.sample(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 226       10.440         15.46           66.62      329.6          0.10530
# 358        8.878         15.49           56.74      241.0          0.08293
# 439       14.020         15.66           89.59      606.5          0.07966
# 478       11.490         14.59           73.99      404.9          0.10460
# 89        14.640         15.24           95.77      651.9          0.11320
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 226           0.07722        0.006643              0.01216         0.1788
# 358           0.07698        0.047210              0.02381         0.1930
# 439           0.05581        0.020870              0.02652         0.1589
# 478           0.08228        0.053080              0.01969         0.1779
# 89            0.13390        0.099660              0.07064         0.2116
#
# ...

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
cancer_df.isnull().sum()[cancer_df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## PLOT SCATTERPLOT & COUNTPLOT USING SEABORN
# - **Seaborn is a visualization library that sits on top of matplotlib**
# - **Seaborn offers enhanced features compared to matplotlib**
# - **https://seaborn.pydata.org/examples/index.html*/*
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Plot scatter plot between mean area and mean smoothness**
# - **Let's print out countplot to know how many samples belong to class #0 and #1**

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
cancer_df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
# ...

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = cancer_df, x = 'mean area', y = 'mean smoothness', color='blue', alpha=0.5)
plt.title('Scatter Plot: Mean Area VS Mean Smoothness')
plt.xlabel('Mean Area')
plt.ylabel('Mean Smoothness')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (8, 4))
sns.countplot(data = cancer_df, x = 'target', color = 'purple',)

plt.title('Countplot of class #0 and #1')
plt.xlabel('Class')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# - **Plot the scatterplot between the mean radius and mean area. Comment on the plot**

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = cancer_df, x = 'mean radius', y = 'mean area')

plt.title('Scatterplot: Mean Radius VS Mean Area')
plt.xlabel('Mean Radius')
plt.ylabel('Mean Area')
plt.show()

# %%
# The points on the plot show an upward trend, this thows a 'Positive' correlation between the two variables (Mean area and mean radius).

# Looking at the general trends, there are no points that significantly deviates from the others. This suggests that there are no outliers
# or anomalies in the dataset

# %% [markdown]
# ## PLOT PAIRPLOT, DISPLOT, AND HEATMAPS/CORRELATIONS USING SEABORN

# %% [markdown]
# - **Plot the pairplot**
# - **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**
# - **plot the distplot**
# - **Displot combines matplotlib histogram function with kdeplot() (Kernel density estimate)**
# - **KDE is used to plot the Probability Density of a continuous variable.**

# %%
columns_of_interest = ['mean radius', 'mean perimeter', 'mean area']
subset_df = cancer_df[columns_of_interest]

sns.pairplot(subset_df)
plt.suptitle('Mean Radius, Mean Perimeter, and Mean Area', y=1.02)

plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.displot(cancer_df['mean radius'], kde=True, bins=40) 

plt.title('Distribution of Mean Radius with KDE')
plt.xlabel('Mean Radius')

plt.show();

# %% [markdown]
# - **Plot two separate distplot for each target class #0 and target class #1**

# %%
class_0_target = cancer_df[cancer_df['target'] == 0]

plt.figure(figsize = (12, 6))

sns.displot(class_0_target['mean radius'], kde = True, bins = 40)
plt.title('Displot of Mean Radius for Class #0')
plt.xlabel('Mean Radius')
plt.ylabel('Density')

plt.tight_layout()
plt.show();

# %%
class_1_target = cancer_df[cancer_df['target'] == 1]

plt.figure(figsize = (12, 6))

sns.displot(class_1_target['mean radius'], kde = True, bins = 40)
plt.title('Displot of Mean Radius for Class #1')
plt.xlabel('Mean Radius')
plt.ylabel('Density')

plt.tight_layout()
plt.show();

# %% [markdown]
# # Daily Stock

# %% [markdown]
# - In this project, we will visualize stock prices using Seaborn and Matplotlib. 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
# - Using the stock_daily_prices.csv and stocks_daily_returns.csv dataset included in the course/workshop package, please do the following:
#     - Import both datasets using Pandas.
#     - Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
#     - Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
#     - Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
#     - Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
#     - Using Seaborn, plot similar scatterplot between Apple and JP Morgan daily returns.
#     - Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#     - Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and Standard deviation for both stocks on top of the figure. What did you conclude from this graph?
#     - Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.
#     - Plot a 3D plot showing all daily returns from JPM, AAPL and UAL [External Research is required].

# %%
sdprice_df = pd.read_csv('stocks_daily_prices.csv')
sdprice_df
# Out:
#            Date        AAPL         JPM          PG        UAL
# 0      1/2/2008    5.949703   29.448614   47.058838  29.915234
# 1      1/3/2008    5.952452   29.246094   47.058838  29.690800
# 2      1/4/2008    5.498071   28.582682   46.870098  31.000002
# 3      1/7/2008    5.424478   28.868999   47.175980  29.180000
# 4      1/8/2008    5.229351   27.723747   47.299629  24.389999
# ...         ...         ...         ...         ...        ...
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999
#
# [3642 rows x 5 columns]

# %%
sdprice_df.head()
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002
# 3  1/7/2008  5.424478  28.868999  47.175980  29.180000
# 4  1/8/2008  5.229351  27.723747  47.299629  24.389999

# %%
sdprice_df.tail()
# Out:
#            Date        AAPL         JPM          PG        UAL
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999

# %%
sdprice_df.sample(5)
# Out:
#             Date       AAPL         JPM         PG        UAL
# 2467  10/18/2017  37.958313   86.283188  81.456230  67.989998
# 2229   11/7/2016  25.910604   60.158787  74.250404  58.529999
# 1626   6/18/2014  20.614733   46.403198  63.172676  43.759998
# 2470  10/23/2017  37.105350   87.471878  77.227730  59.099998
# 2707   10/2/2018  55.299679  101.939362  76.580452  86.709999

# %%
sdprice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
sdprice_df.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
sdreturns_df = pd.read_csv('stocks_daily_returns.csv')
sdreturns_df
# Out:
#            Date      AAPL       JPM        PG        UAL
# 0      1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1      1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2      1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3      1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4      1/8/2008 -3.597157 -3.967066  0.262103 -16.415356
# ...         ...       ...       ...       ...        ...
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824
#
# [3642 rows x 5 columns]

# %%
sdreturns_df.head()
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %%
sdreturns_df.tail()
# Out:
#            Date      AAPL       JPM        PG        UAL
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824

# %%
sdreturns_df.sample(5)
# Out:
#            Date      AAPL       JPM        PG       UAL
# 1273  1/23/2013  1.830529 -0.666065  1.057892 -0.793654
# 1938  9/14/2015  0.963140 -0.287712 -0.526158  1.090971
# 1324   4/8/2013  0.711241  1.398503  0.715854  2.664840
# 2522   1/8/2018 -0.371425  0.147681  0.526078 -1.225488
# 2297  2/15/2017  0.362897  1.150043  3.710463  2.725796

# %%
sdreturns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
sdreturns_df.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
sdreturns_df
# Out:
#            Date      AAPL       JPM        PG        UAL
# 0      1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1      1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2      1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3      1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4      1/8/2008 -3.597157 -3.967066  0.262103 -16.415356
# ...         ...       ...       ...       ...        ...
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824
#
# [3642 rows x 5 columns]

# %%
sdprice_df
# Out:
#            Date        AAPL         JPM          PG        UAL
# 0      1/2/2008    5.949703   29.448614   47.058838  29.915234
# 1      1/3/2008    5.952452   29.246094   47.058838  29.690800
# 2      1/4/2008    5.498071   28.582682   46.870098  31.000002
# 3      1/7/2008    5.424478   28.868999   47.175980  29.180000
# 4      1/8/2008    5.229351   27.723747   47.299629  24.389999
# ...         ...         ...         ...         ...        ...
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999
#
# [3642 rows x 5 columns]

# %%
import matplotlib.dates as mdates

# %%
plt.figure(figsize = (10, 4))

plt.plot(sdprice_df['Date'], sdprice_df['AAPL'], label='AAPL', linestyle='-', linewidth=0.5)
plt.plot(sdprice_df['Date'], sdprice_df['JPM'], label='JPM', linestyle='-', linewidth=0.5)
plt.plot(sdprice_df['Date'], sdprice_df['PG'], label='PG', linestyle='-', linewidth=0.5)
plt.plot(sdprice_df['Date'], sdprice_df['UAL'], label='UAL', linestyle='-', linewidth=0.5)

plt.title('Daily Prices of 4 Stocks', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=150))
plt.xticks(rotation=45, ha='left')
plt.legend(loc='upper left', fontsize=12)
plt.tight_layout() 

plt.show();

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

ax[0, 0].plot(sdprice_df['Date'], sdprice_df['AAPL'], label='AAPL', color='b')
ax[0, 0].set_title('AAPL Daily Prices')
ax[0, 0].set_xlabel('Date')
ax[0, 0].set_ylabel('Price')
ax[0, 0].tick_params(axis='x', rotation=45)
ax[0, 0].xaxis.set_major_locator(mdates.DayLocator(interval=160))

ax[0, 1].plot(sdprice_df['Date'], sdprice_df['JPM'], label='JPM', color='g')
ax[0, 1].set_title('JPM Daily Prices')
ax[0, 1].set_xlabel('Date')
ax[0, 1].set_ylabel('Price')
ax[0, 1].tick_params(axis='x', rotation=45)
ax[0, 1].xaxis.set_major_locator(mdates.DayLocator(interval=160))

ax[1, 0].plot(sdprice_df['Date'], sdprice_df['PG'], label='PG', color='r')
ax[1, 0].set_title('PG Daily Prices')
ax[1, 0].set_xlabel('Date')
ax[1, 0].set_ylabel('Price')
ax[1, 0].tick_params(axis='x', rotation=45)
ax[1, 0].xaxis.set_major_locator(mdates.DayLocator(interval=160))

ax[1, 1].plot(sdprice_df['Date'], sdprice_df['UAL'], label='UAL', color='purple')
ax[1, 1].set_title('UAL Daily Prices')
ax[1, 1].set_xlabel('Date')
ax[1, 1].set_ylabel('Price')
ax[1, 1].tick_params(axis='x', rotation=45)
ax[1, 1].xaxis.set_major_locator(mdates.DayLocator(interval=160))

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))

ax[0].plot(sdprice_df['Date'], sdprice_df['AAPL'], label='AAPL', color='b')
ax[0].set_title('AAPL Daily Prices')
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Price')
ax[0].tick_params(axis='x', rotation=45)
ax[0].xaxis.set_major_locator(mdates.DayLocator(interval=150))

ax[1].plot(sdprice_df['Date'], sdprice_df['JPM'], label='JPM', color='g')
ax[1].set_title('JPM Daily Prices')
ax[1].set_xlabel('Date')
ax[1].set_ylabel('Price')
ax[1].tick_params(axis='x', rotation=45)
ax[1].xaxis.set_major_locator(mdates.DayLocator(interval=150))

ax[2].plot(sdprice_df['Date'], sdprice_df['PG'], label='PG', color='r')
ax[2].set_title('PG Daily Prices')
ax[2].set_xlabel('Date')
ax[2].set_ylabel('Price')
ax[2].tick_params(axis='x', rotation=45)
ax[2].xaxis.set_major_locator(mdates.DayLocator(interval=150))

ax[3].plot(sdprice_df['Date'], sdprice_df['UAL'], label='UAL', color='purple')
ax[3].set_title('UAL Daily Prices')
ax[3].set_xlabel('Date')
ax[3].set_ylabel('Price')
ax[3].tick_params(axis='x', rotation=45)
ax[3].xaxis.set_major_locator(mdates.DayLocator(interval=150))

plt.tight_layout()
plt.show()

# %%
sdreturns_df
# Out:
#            Date      AAPL       JPM        PG        UAL
# 0      1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1      1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2      1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3      1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4      1/8/2008 -3.597157 -3.967066  0.262103 -16.415356
# ...         ...       ...       ...       ...        ...
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824
#
# [3642 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))

plt.scatter(sdreturns_df['AAPL'], sdreturns_df['JPM'], alpha=0.6, color='b')

plt.title('Scatter Plot of Daily Returns: AAPL vs. JPM', fontsize=16)
plt.xlabel('AAPL Daily Returns', fontsize=14)
plt.ylabel('JPM Daily Returns', fontsize=14)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data = sdreturns_df, x = 'AAPL', y = 'JPM', color = 'b', alpha = 0.6)

plt.title('Scatter Plot of Daily Returns: AAPL vs. JPM', fontsize = 16)
plt.xlabel('AAPL Daily Returns', fontsize = 14)
plt.ylabel('JPM Daily Returns', fontsize = 14)

plt.tight_layout()
plt.show()

# %%
labels = ['AAPL', 'JPM', 'PG', 'UAL']

sizes = [70, 10, 10, 10]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0)

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode, shadow=True)

plt.title('Asset Allocation of Portfolio', fontsize=16)

plt.tight_layout()
plt.show()

# %%
std_pg = sdreturns_df['PG'].std()
std_pg
# Out:
# 1.1989770738608498

# %%
mean_ual = sdreturns_df['UAL'].mean()
std_ual = sdreturns_df['UAL'].std()

mean_pg = sdreturns_df['PG'].mean()
std_pg = sdreturns_df['PG'].std()

plt.figure(figsize=(10, 6))

plt.hist(sdreturns_df['UAL'], bins=40, alpha=0.5, color='red', label='UAL Returns')

plt.hist(sdreturns_df['PG'], bins=40, alpha=0.5, color='red', label='PG Returns')

plt.text(-30, 350, f'UAL Mean: {mean_ual:.4f}\nUAL Std Dev: {std_ual:.4f}', fontsize=12, color='black')
plt.text(10, 250, f'PG Mean: {mean_pg:.4f}\nPG Std Dev: {std_pg:.4f}', fontsize=12, color='black')

plt.title('Histogram of Daily Returns for UAL and PG', fontsize=16)
plt.xlabel('Daily Returns', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

plt.legend()
plt.tight_layout()
plt.show()

# %%
corr_matrix = sdreturns_df[['AAPL', 'JPM', 'PG', 'UAL']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f', linewidths=0.5)

plt.title('Correlation Matrix of Daily Returns of Stocks', fontsize=16)
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

jpm_returns = sdreturns_df['JPM']
aapl_returns = sdreturns_df['AAPL']
ual_returns = sdreturns_df['UAL']

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(jpm_returns, aapl_returns, ual_returns, c='blue', marker='o', alpha=0.5)

ax.set_xlabel('JPM Daily Returns')
ax.set_ylabel('AAPL Daily Returns')
ax.set_zlabel('UAL Daily Returns')
ax.set_title('3D Scatter Plot of Daily Returns: JPM, AAPL, and UAL')

plt.tight_layout()
plt.show()

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Human Resources & Kyphosis & Cancer & Daily Stock Project</b></p>
